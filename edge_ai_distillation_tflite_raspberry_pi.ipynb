# %% [markdown]
# # **Knowledge Distillation with Quantization and Deployment on Raspberry Pi**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# This notebook explores an end-to-end edge-AI model compression pipeline for CIFAR-10 image classification. The workflow combines **knowledge distillation**, **TensorFlow Lite quantization**, and **Raspberry Pi deployment** to study how a smaller student model can retain useful performance while becoming more efficient for edge-device inference.
#
# The notebook is organized into four main parts:
#
# 1. **Teacher Model Training**
#    A higher-capacity teacher model is implemented and trained on CIFAR-10. The teacher provides stronger supervision for the student model through soft probability outputs.
#
# 2. **Student Model Distillation**
#    A lightweight student model is trained using knowledge distillation. The student learns from both the ground-truth labels and the softened outputs of the teacher model.
#
# 3. **TensorFlow Lite Quantization**
#    The trained student model is converted into TensorFlow Lite format using FP16 and INT8 quantization. This reduces model size and prepares the model for deployment on resource-constrained hardware.
#
# 4. **Raspberry Pi Deployment and Benchmarking**
#    The quantized models are deployed on a Raspberry Pi 4. Inference is run on sample CIFAR-10 images while measuring prediction results, inference time, CPU usage, memory usage, and CPU temperature.
#
# The main goal is to compare the trade-offs between accuracy, compression, latency, and real edge-device performance. By the end of the notebook, we can evaluate whether quantization and knowledge distillation make the student model more practical for deployment without significantly changing its prediction behavior.

# %% [markdown]
# ## **Initialization**
#
# In this section, we install and import all required dependencies. This cell sets up the environment to ensure that the necessary packages are available for the notebook. Since we are using Google Colab, these commands will automatically install missing libraries.

# %%
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

SEED = 31
random.seed(SEED)
np.random.seed(SEED)
tf.keras.utils.set_random_seed(SEED)

# %% [markdown]
# # **Knowledge Distillation: An Overview**
# In the next section, we'll implement the teacher–student training loop using knowledge distillation.

# %% [markdown]
# ## **What is Knowledge Distillation?**
# Knowledge distillation is a model compression technique where a **large, complex model (teacher)** transfers its learned knowledge to a **smaller, more efficient model (student)**. Instead of training the student model solely on ground-truth labels, distillation incorporates **soft labels**—the probability distributions output by the teacher. These soft labels provide additional information about the relationships between classes, making the student model more generalizable.
#
# <img src="https://github.com/shawnyin128/NYU-EfficientAI-Materials/raw/master/graph/l26sp-lab3-1.png" width="800">

# %% [markdown]
# ## **1. The Distillation Loss Function**
#
# To effectively transfer knowledge, the student model is trained using a **distillation loss** that minimizes the difference between the teacher’s and student’s probability distributions. This is typically measured using **Kullback-Leibler (KL) divergence**.
#
# ### **Mathematical Formulation**
# Let:
# - $z_i^T$ and $z_i^S$ be the logits (pre-softmax outputs) from the teacher and student models for class $i$.
#
# We introduce a **temperature factor** $T$, which smooths the probability distributions to create "softened" logits:
#
# $$
# \tilde{z}_i^T = z_i^T \Big/ T \quad \text{and} \quad \tilde{z}_i^S = z_i^S \Big/ T
# $$
#
# ### **Softmax and Log-Softmax**
#
# The teacher's and student's softened probability distributions are obtained using the **softmax function**:
#
# $$
# \tilde{p}_i = e^{\tilde{z}_i^T} \Big/ \sum_{j} e^{\tilde{z}_j^T}
# $$
#
# $$
# \tilde{q}_i = e^{\tilde{z}_i^S} \Big/ \sum_{j} e^{\tilde{z}_j^S}
# $$
#
# Where:
# - $\tilde{p}_i$ represents the teacher’s softened probability distribution.
# - $\tilde{q}_i$ represents the student’s softened probability distribution.
#
# In practical code implementations, to ensure numerical stability when calculating the loss, we often apply the **log-softmax** function to the student's logits to directly obtain $\log(\tilde{q}_i)$ instead of computing the raw probability first
#
# ### **KL Divergence Calculation**
# The **KL divergence** measures the difference between these distributions:
#
# $$
# D_{KL}(\tilde{P} || \tilde{Q}) = \sum_{i} \tilde{p}_i \log \Big( \tilde{p}_i \Big/ \tilde{q}_i \Big)
# $$
#
# ### **Final Distillation Loss**
# The final **distillation loss** is:
#
# $$
# L_{\text{distill}} = T^2 \cdot D_{KL}(\tilde{P} || \tilde{Q})
# $$
#
# where the factor $T^2$ ensures that the gradients remain properly scaled after being divided by the temperature during the logit softening step.

# %% [markdown]
# ---
# ## **2. Structure of the Distillation Process**
#
# A knowledge distillation framework typically consists of two main components:
#
# ### **Teacher Model**
# - A **pretrained, larger model** that has already been trained on the dataset.
# - Provides **soft probability distributions** as supervision for the student.
# - Remains **frozen** during student training.
#
# ### **Student Model**
# - A **smaller, lightweight model** designed to approximate the teacher's behavior.
# - Learns using a combination of **hard loss (cross entropy loss)** and **soft loss (distillation loss).**
#
# The total loss function used to train the student is a **weighted sum** of these two losses:
#
# $$
# L_{\text{total}} = \alpha L_{\text{CrossEntropy}} + (1 - \alpha) L_{\text{Distill}}
# $$
#
# where:
# - $ \alpha $ balances the contribution of the **cross entropy loss** (standard classification loss) and **distillation loss**.
# - $ L_{\text{hard}} $ is the normal classification loss, such as cross-entropy.

# %% [markdown]
# ---
# ## **3. High-Level Structure of a Distillation Framework**
# The typical implementation follows this structure:
#
# ### **Step 1: Compute Teacher Predictions**
# - The teacher model generates probability distributions $ P^{(T)} $.
#
# ### **Step 2: Compute Student Predictions**
# - The student model generates probability distributions $ Q^{(T)} $.
#
# ### **Step 3: Compute Losses**
# - Compute **cross entropy loss** using standard classification loss.
# - Compute **distill loss** using KL divergence between teacher and student outputs.
#
# ### **Step 4: Update Student Model**
# - Compute gradients with respect to the student model’s parameters.
# - Optimize the student using a **gradient descent optimizer**.

# %% [markdown]
# # **Knowledge Distillation: Teacher Model**

# %% [markdown]
# ## What are teacher models ?

# %% [markdown]
# Teacher models are typically large, high-capacity neural networks that achieve high accuracy on complex datasets. In knowledge distillation, the teacher model serves as a reference from which a smaller, more efficient student model learns. Although the teacher model might be computationally heavy, its robust performance makes it ideal for guiding the training of the student model. In this lab, while we will eventually work with a Hybrid MicroVIT architecture for the teacher model, here’s a sample implementation using a simpler Convolutional Neural Network (CNN) to illustrate the overall approach.

# %% [markdown]
# ## Sample Teacher Model Implementation (Simple CNN)

# %%
# Define the simple teacher model
def simple_teacher_model(input_shape=(32, 32, 3), num_classes=10):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), padding='same'),
        layers.ReLU(),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# Create and compile the teacher model
teacher_model = simple_teacher_model()
teacher_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# Load and normalize CIFAR‑10 data
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Train the teacher model
history = teacher_model.fit(train_images, train_labels,
                            epochs=5,
                            batch_size=64,
                            validation_data=(test_images, test_labels))

# Evaluate the model on the test data
test_loss, test_acc = teacher_model.evaluate(test_images, test_labels, verbose=2)
print("Test accuracy:", test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4813 - loss: 1.4468 - val_accuracy: 0.5948 - val_loss: 1.1626
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6248 - loss: 1.0685 - val_accuracy: 0.6448 - val_loss: 1.0061
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6769 - loss: 0.9266 - val_accuracy: 0.6665 - val_loss: 0.9427
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7100 - loss: 0.8346 - val_accuracy: 0.6862 - val_loss: 0.9017
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7378 - loss: 0.7583 - val_accuracy: 0.6924 - val_loss: 0.8982
# 313/313 - 1s - 4ms/step - accuracy: 0.6924 - loss: 0.8982
# Test accuracy: 0.6923999786376953

# %% [markdown]
# ### Evaluating the Sample Teacher Model Performance
#
# Our simple CNN teacher model achieved about **65% - 70% accuracy** on CIFAR-10. For effective knowledge distillation, it's crucial to have a high-performing teacher because:
#
# - **Enhanced Guidance:** A more accurate teacher provides richer and more reliable soft targets for the student.
# - **Better Representations:** High accuracy suggests that the teacher has learned robust feature representations, which are vital for the student to mimic.
# - **Performance Benchmark:** A significant performance gap between teacher and student drives the student to learn and improve.
#
# In our next steps, we will work on refining the teacher model to ensure it sets a strong foundation for the student model.

# %% [markdown]
# # **Teacher Model Implementation**

# %% [markdown]
# <img src="https://github.com/shawnyin128/NYU-EfficientAI-Materials/raw/master/graph/l26sp-lab3-2.png" width="800">
#
# The provided skeleton is a lightweight version of **$ViT_C$** from [Early Convolutions Help Transformers See Better
# ](https://arxiv.org/pdf/2106.14881). Hybrid ViTs combine the advantages of CNN and ViT. In particular, the CNN stem of $ViT_C$ increases optimization stability and also improves peak performance.

# %% [markdown]
# ## Section 1: Transformer Block

# %%
def mlp(x, hidden_units, dropout_rate):
    """Provided MLP block for the Transformer"""
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

def transformer_block(inputs, projection_dim, num_heads, mlp_dim, dropout_rate=0.1):
    epsilon = 1e-6

    # Apply Layer Normalization to the inputs
    x1 = layers.LayerNormalization(epsilon=epsilon)(inputs)

    # Create a Multi-Head Attention layer and pass x1 through it
    # Apply it as Self-Attention (query, key, and value are all x1).
    mha_layer = layers.MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim)
    x2 = mha_layer(query=x1, key=x1, value=x1)

    # Add the first shortcut connection
    shortcut1 = layers.Add()([inputs, x2])

    # Apply another Layer Normalization to x2
    x3 = layers.LayerNormalization(epsilon=epsilon)(shortcut1)

    # Apply the MLP block to x3 (use the provided mlp function)
    # hidden_units must be a list to ensure residual shape matching.
    x4 = mlp(x3, [mlp_dim, projection_dim], dropout_rate)

    # Add the second shortcut connection and return
    shortcut2 = layers.Add()([shortcut1, x4])

    out = shortcut2

    return out

# %% [markdown]
# ## Section 2: Hybrid ViT Model

# %%
def HybridViT(input_shape=(32, 32, 3), num_classes=10,
                   projection_dim=128, num_heads=4,
                   transformer_layers=4, mlp_dim=256):

    inputs = layers.Input(shape=input_shape)
    padding = "same"
    use_bias = False
    num_patches = 64
    epsilon = 1e-6

    he_init = tf.keras.initializers.HeNormal()

    # -------------------- Conv Stem ---------------------
    # 1st Conv (64 channels, 3x3 kernel, stride 2)
    layer1 = layers.Conv2D(64, kernel_size=3, strides=2, padding=padding, use_bias=use_bias, kernel_initializer=he_init)(inputs)
    bn1 = layers.BatchNormalization(epsilon=epsilon)(layer1)
    relu1 = layers.ReLU()(bn1)

    # 2nd Conv (64 channels, 3x3 kernel, stride 1)
    layer2 =  layers.Conv2D(64, kernel_size=3, strides=1, padding=padding, use_bias=use_bias, kernel_initializer=he_init)(relu1)
    bn2 = layers.BatchNormalization(epsilon=epsilon)(layer2)
    relu2 = layers.ReLU()(bn2)

    # 3rd Conv (128 channels, 3x3 kernel, stride 2)
    layer3 = layers.Conv2D(128, kernel_size=3, strides=2, padding=padding, use_bias=use_bias, kernel_initializer=he_init)(relu2)
    bn3 = layers.BatchNormalization(epsilon=epsilon)(layer3)
    relu3 = layers.ReLU()(bn3)

    # 4th Conv (128 channels, 3x3 kernel, stride 1)
    layer4 = layers.Conv2D(128, kernel_size=3, strides=1, padding=padding, use_bias=use_bias, kernel_initializer=he_init)(relu3)
    bn4 = layers.BatchNormalization(epsilon=epsilon)(layer4)
    relu4 = layers.ReLU()(bn4)

    # last Conv (projection_dim, 1x1 kernel, stride 1)
    layer5 = layers.Conv2D(projection_dim, kernel_size=1, strides=1, padding=padding, use_bias=use_bias, kernel_initializer=he_init)(relu4)

    x = layer5

    # Positional embedding
    encoded_patches = layers.Reshape((num_patches, projection_dim))(x)
    positions = tf.range(start=0, limit=num_patches)
    position_embedding = layers.Embedding(
        input_dim=num_patches, output_dim=projection_dim
    )(positions)
    encoded_patches = encoded_patches + position_embedding

    # Stack transformer layers
    for _ in range(transformer_layers):
        encoded_patches = transformer_block(encoded_patches, projection_dim, num_heads, mlp_dim)

    representation = layers.LayerNormalization(epsilon=epsilon)(encoded_patches)
    representation = layers.GlobalAveragePooling1D()(representation)
    outputs = layers.Dense(num_classes, activation='softmax')(representation)

    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Section 3: Compile and Train

# %%
# load model
teacher_model = HybridViT()

#  Optimizer AdamW
teacher_model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Load and normalize CIFAR‑10 data
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Set up data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    shear_range=0.1,
    zoom_range=0.1
)

datagen.fit(train_images)

# Training Config
batch_size = 128
epochs = 30

# Calculate how many steps are in one epoch
steps_per_epoch = len(train_images) // batch_size

# Create the generator to pull batches from
train_gen = datagen.flow(train_images, train_labels, batch_size=batch_size)

# Loss Function
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()

# Cosine learning-rate schedule parameters
initial_lr = 1e-3
min_lr = 1e-5
total_steps = epochs * steps_per_epoch
global_step = 0

# Best-checkpoint / early stopping
best_acc = 0.0
best_weights = None
patience = 5
wait = 0

# Train your model using the augmented data
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    for step in range(steps_per_epoch):
        # Manual cosine decay
        cosine_decay = 0.5 * (1 + np.cos(np.pi * global_step / total_steps))
        current_lr = min_lr + (initial_lr - min_lr) * cosine_decay
        teacher_model.optimizer.learning_rate.assign(current_lr)

        # Pull a batch of augmented data
        x_batch, y_batch = next(train_gen)

        with tf.GradientTape() as tape:
          preds  = teacher_model(x_batch, training=True)
          loss = loss_fn(y_batch, preds )

        grads = tape.gradient(loss, teacher_model.trainable_weights)
        teacher_model.optimizer.apply_gradients(zip(grads, teacher_model.trainable_weights))

        # Log every 100 batches
        if step % 100 == 0:
            batch_preds = tf.argmax(preds, axis=1, output_type=tf.int32)
            batch_labels = tf.reshape(tf.cast(y_batch, tf.int32), [-1])
            batch_acc = tf.reduce_mean(
                tf.cast(tf.equal(batch_preds, batch_labels), tf.float32)
            )
            print(
                f"Epoch {epoch + 1}/{epochs} | "
                f"Step {step + 1}/{steps_per_epoch} | "
                f"LR: {float(current_lr):.6f} | "
                f"Batch loss: {float(loss):.4f} | "
                f"Batch acc: {float(batch_acc) * 100:.2f}%"
            )

        global_step += 1

    # Epoch-end validation accuracy
    val_loss, val_acc = teacher_model.evaluate(test_images, test_labels, verbose=0)
    print(
        f"End of epoch {epoch + 1} | "
        f"Val loss: {val_loss:.4f} | "
        f"Val acc: {val_acc * 100:.2f}%", "\n"
    )

    # Save best model
    if val_acc > best_acc:
        best_acc = val_acc
        best_weights = teacher_model.get_weights()
        wait = 0
        print(f"New best model: {best_acc * 100:.2f}%")
    else:
        wait += 1
        print(f"No improvement for {wait} epoch(s)")

    # Early stopping
    if wait >= patience:
        print("Early stopping triggered.")
        break

# Restore best weights before the provided save() cell runs
if best_weights is not None:
    teacher_model.set_weights(best_weights)
    print(f"Restored best model with accuracy: {best_acc * 100:.2f}%")
# Out:
# Epoch 1/30
# Epoch 1/30 | Step 1/390 | LR: 0.001000 | Batch loss: 2.4003 | Batch acc: 14.06%
# Epoch 1/30 | Step 101/390 | LR: 0.001000 | Batch loss: 1.6882 | Batch acc: 35.16%
# Epoch 1/30 | Step 201/390 | LR: 0.000999 | Batch loss: 1.4222 | Batch acc: 41.41%
# Epoch 1/30 | Step 301/390 | LR: 0.000998 | Batch loss: 1.2872 | Batch acc: 51.56%
# End of epoch 1 | Val loss: 1.5173 | Val acc: 46.96%
#
# New best model: 46.96%
# Epoch 2/30
# Epoch 2/30 | Step 1/390 | LR: 0.000997 | Batch loss: 1.0965 | Batch acc: 58.75%
# Epoch 2/30 | Step 101/390 | LR: 0.000996 | Batch loss: 1.0795 | Batch acc: 57.03%
# Epoch 2/30 | Step 201/390 | LR: 0.000994 | Batch loss: 1.1715 | Batch acc: 56.25%
# Epoch 2/30 | Step 301/390 | LR: 0.000992 | Batch loss: 1.1448 | Batch acc: 56.25%
# End of epoch 2 | Val loss: 1.0422 | Val acc: 63.43%
#
# New best model: 63.43%
# Epoch 3/30
# Epoch 3/30 | Step 1/390 | LR: 0.000989 | Batch loss: 1.0863 | Batch acc: 63.28%
# Epoch 3/30 | Step 101/390 | LR: 0.000986 | Batch loss: 0.9893 | Batch acc: 60.94%
# Epoch 3/30 | Step 201/390 | LR: 0.000983 | Batch loss: 0.8036 | Batch acc: 69.53%
# Epoch 3/30 | Step 301/390 | LR: 0.000979 | Batch loss: 0.8774 | Batch acc: 66.41%
# End of epoch 3 | Val loss: 1.0361 | Val acc: 64.39%
#
# New best model: 64.39%
# Epoch 4/30
# Epoch 4/30 | Step 1/390 | LR: 0.000976 | Batch loss: 0.9263 | Batch acc: 68.75%
# Epoch 4/30 | Step 101/390 | LR: 0.000971 | Batch loss: 1.0038 | Batch acc: 60.94%
# Epoch 4/30 | Step 201/390 | LR: 0.000967 | Batch loss: 0.8211 | Batch acc: 73.44%
# Epoch 4/30 | Step 301/390 | LR: 0.000962 | Batch loss: 0.7644 | Batch acc: 71.09%
# End of epoch 4 | Val loss: 0.9795 | Val acc: 66.56%
#
# New best model: 66.56%
# Epoch 5/30
# Epoch 5/30 | Step 1/390 | LR: 0.000957 | Batch loss: 0.8366 | Batch acc: 67.97%
# Epoch 5/30 | Step 101/390 | LR: 0.000952 | Batch loss: 0.6879 | Batch acc: 75.78%
# Epoch 5/30 | Step 201/390 | LR: 0.000946 | Batch loss: 0.7426 | Batch acc: 68.75%
# Epoch 5/30 | Step 301/390 | LR: 0.000940 | Batch loss: 0.8122 | Batch acc: 71.09%
# End of epoch 5 | Val loss: 1.0219 | Val acc: 66.08%
#
# No improvement for 1 epoch(s)
# Epoch 6/30
# Epoch 6/30 | Step 1/390 | LR: 0.000934 | Batch loss: 0.8683 | Batch acc: 72.66%
# Epoch 6/30 | Step 101/390 | LR: 0.000927 | Batch loss: 0.9985 | Batch acc: 62.50%
# Epoch 6/30 | Step 201/390 | LR: 0.000920 | Batch loss: 0.8439 | Batch acc: 68.75%
# Epoch 6/30 | Step 301/390 | LR: 0.000912 | Batch loss: 0.6486 | Batch acc: 73.44%
# End of epoch 6 | Val loss: 0.7588 | Val acc: 74.16%
#
# New best model: 74.16%
# Epoch 7/30
# Epoch 7/30 | Step 1/390 | LR: 0.000905 | Batch loss: 0.7022 | Batch acc: 73.44%
# Epoch 7/30 | Step 101/390 | LR: 0.000898 | Batch loss: 0.6216 | Batch acc: 77.34%
# Epoch 7/30 | Step 201/390 | LR: 0.000889 | Batch loss: 0.7491 | Batch acc: 75.78%
# Epoch 7/30 | Step 301/390 | LR: 0.000881 | Batch loss: 0.6593 | Batch acc: 72.66%
# End of epoch 7 | Val loss: 0.9054 | Val acc: 69.59%
#
# No improvement for 1 epoch(s)
# Epoch 8/30
# Epoch 8/30 | Step 1/390 | LR: 0.000873 | Batch loss: 0.6944 | Batch acc: 74.22%
# Epoch 8/30 | Step 101/390 | LR: 0.000864 | Batch loss: 0.5695 | Batch acc: 83.59%
# Epoch 8/30 | Step 201/390 | LR: 0.000855 | Batch loss: 0.7741 | Batch acc: 75.78%
# Epoch 8/30 | Step 301/390 | LR: 0.000845 | Batch loss: 0.7616 | Batch acc: 73.44%
# End of epoch 8 | Val loss: 0.7896 | Val acc: 72.73%
#
# No improvement for 2 epoch(s)
# Epoch 9/30
# Epoch 9/30 | Step 1/390 | LR: 0.000836 | Batch loss: 0.6833 | Batch acc: 75.00%
# Epoch 9/30 | Step 101/390 | LR: 0.000826 | Batch loss: 0.5674 | Batch acc: 78.12%
# Epoch 9/30 | Step 201/390 | LR: 0.000816 | Batch loss: 0.5424 | Batch acc: 82.81%
# Epoch 9/30 | Step 301/390 | LR: 0.000806 | Batch loss: 0.7546 | Batch acc: 74.22%
# End of epoch 9 | Val loss: 0.6949 | Val acc: 76.34%
#
# New best model: 76.34%
# Epoch 10/30
# Epoch 10/30 | Step 1/390 | LR: 0.000796 | Batch loss: 0.6571 | Batch acc: 78.91%
# Epoch 10/30 | Step 101/390 | LR: 0.000785 | Batch loss: 0.6606 | Batch acc: 81.25%
# Epoch 10/30 | Step 201/390 | LR: 0.000774 | Batch loss: 0.6831 | Batch acc: 78.91%
# Epoch 10/30 | Step 301/390 | LR: 0.000763 | Batch loss: 0.5481 | Batch acc: 82.03%
# End of epoch 10 | Val loss: 0.6041 | Val acc: 79.70%
#
# New best model: 79.70%
# Epoch 11/30
# Epoch 11/30 | Step 1/390 | LR: 0.000753 | Batch loss: 0.6777 | Batch acc: 75.78%
# Epoch 11/30 | Step 101/390 | LR: 0.000741 | Batch loss: 0.4349 | Batch acc: 85.94%
# Epoch 11/30 | Step 201/390 | LR: 0.000729 | Batch loss: 0.5461 | Batch acc: 77.34%
# Epoch 11/30 | Step 301/390 | LR: 0.000717 | Batch loss: 0.8040 | Batch acc: 73.44%
# End of epoch 11 | Val loss: 0.7841 | Val acc: 74.76%
#
# No improvement for 1 epoch(s)
# Epoch 12/30
# Epoch 12/30 | Step 1/390 | LR: 0.000706 | Batch loss: 0.4914 | Batch acc: 79.69%
# Epoch 12/30 | Step 101/390 | LR: 0.000694 | Batch loss: 0.4980 | Batch acc: 82.81%
# Epoch 12/30 | Step 201/390 | LR: 0.000682 | Batch loss: 0.5071 | Batch acc: 78.12%
# Epoch 12/30 | Step 301/390 | LR: 0.000669 | Batch loss: 0.6719 | Batch acc: 75.00%
# End of epoch 12 | Val loss: 0.6206 | Val acc: 78.71%
#
# No improvement for 2 epoch(s)
# Epoch 13/30
# Epoch 13/30 | Step 1/390 | LR: 0.000658 | Batch loss: 0.3797 | Batch acc: 86.72%
# Epoch 13/30 | Step 101/390 | LR: 0.000645 | Batch loss: 0.4291 | Batch acc: 82.81%
# Epoch 13/30 | Step 201/390 | LR: 0.000632 | Batch loss: 0.5274 | Batch acc: 81.25%
# Epoch 13/30 | Step 301/390 | LR: 0.000620 | Batch loss: 0.4108 | Batch acc: 84.38%
# End of epoch 13 | Val loss: 0.6298 | Val acc: 78.94%
#
# No improvement for 3 epoch(s)
# Epoch 14/30
# Epoch 14/30 | Step 1/390 | LR: 0.000608 | Batch loss: 0.5550 | Batch acc: 81.25%
# Epoch 14/30 | Step 101/390 | LR: 0.000595 | Batch loss: 0.3988 | Batch acc: 89.84%
# Epoch 14/30 | Step 201/390 | LR: 0.000582 | Batch loss: 0.4271 | Batch acc: 84.38%
# Epoch 14/30 | Step 301/390 | LR: 0.000569 | Batch loss: 0.4212 | Batch acc: 85.94%
# End of epoch 14 | Val loss: 0.7139 | Val acc: 77.61%
#
# No improvement for 4 epoch(s)
# Epoch 15/30
# Epoch 15/30 | Step 1/390 | LR: 0.000557 | Batch loss: 0.4607 | Batch acc: 82.81%
# Epoch 15/30 | Step 101/390 | LR: 0.000544 | Batch loss: 0.5774 | Batch acc: 78.91%
# Epoch 15/30 | Step 201/390 | LR: 0.000530 | Batch loss: 0.3650 | Batch acc: 82.81%
# Epoch 15/30 | Step 301/390 | LR: 0.000517 | Batch loss: 0.4782 | Batch acc: 81.25%
# End of epoch 15 | Val loss: 0.5715 | Val acc: 80.88%
#
# New best model: 80.88%
# Epoch 16/30
# Epoch 16/30 | Step 1/390 | LR: 0.000505 | Batch loss: 0.3704 | Batch acc: 86.72%
# Epoch 16/30 | Step 101/390 | LR: 0.000492 | Batch loss: 0.3937 | Batch acc: 84.38%
# Epoch 16/30 | Step 201/390 | LR: 0.000478 | Batch loss: 0.4008 | Batch acc: 86.72%
# Epoch 16/30 | Step 301/390 | LR: 0.000465 | Batch loss: 0.4073 | Batch acc: 88.28%
# End of epoch 16 | Val loss: 0.5842 | Val acc: 80.63%
#
# No improvement for 1 epoch(s)
# Epoch 17/30
# Epoch 17/30 | Step 1/390 | LR: 0.000453 | Batch loss: 0.3458 | Batch acc: 85.94%
# Epoch 17/30 | Step 101/390 | LR: 0.000440 | Batch loss: 0.4405 | Batch acc: 85.94%
# Epoch 17/30 | Step 201/390 | LR: 0.000427 | Batch loss: 0.5095 | Batch acc: 84.38%
# Epoch 17/30 | Step 301/390 | LR: 0.000414 | Batch loss: 0.3524 | Batch acc: 87.50%
# End of epoch 17 | Val loss: 0.5303 | Val acc: 82.45%
#
# New best model: 82.45%
# Epoch 18/30
# Epoch 18/30 | Step 1/390 | LR: 0.000402 | Batch loss: 0.5143 | Batch acc: 81.25%
# Epoch 18/30 | Step 101/390 | LR: 0.000389 | Batch loss: 0.5409 | Batch acc: 83.59%
# Epoch 18/30 | Step 201/390 | LR: 0.000376 | Batch loss: 0.4262 | Batch acc: 85.16%
# Epoch 18/30 | Step 301/390 | LR: 0.000363 | Batch loss: 0.4084 | Batch acc: 85.16%
# End of epoch 18 | Val loss: 0.5478 | Val acc: 81.88%
#
# No improvement for 1 epoch(s)
# Epoch 19/30
# Epoch 19/30 | Step 1/390 | LR: 0.000352 | Batch loss: 0.4381 | Batch acc: 86.72%
# Epoch 19/30 | Step 101/390 | LR: 0.000339 | Batch loss: 0.2629 | Batch acc: 89.06%
# Epoch 19/30 | Step 201/390 | LR: 0.000327 | Batch loss: 0.2943 | Batch acc: 91.41%
# Epoch 19/30 | Step 301/390 | LR: 0.000315 | Batch loss: 0.2628 | Batch acc: 91.41%
# End of epoch 19 | Val loss: 0.5565 | Val acc: 82.41%
#
# No improvement for 2 epoch(s)
# Epoch 20/30
# Epoch 20/30 | Step 1/390 | LR: 0.000304 | Batch loss: 0.5484 | Batch acc: 79.69%
# Epoch 20/30 | Step 101/390 | LR: 0.000292 | Batch loss: 0.4994 | Batch acc: 82.81%
# Epoch 20/30 | Step 201/390 | LR: 0.000280 | Batch loss: 0.4331 | Batch acc: 85.16%
# Epoch 20/30 | Step 301/390 | LR: 0.000268 | Batch loss: 0.3309 | Batch acc: 89.84%
# End of epoch 20 | Val loss: 0.5131 | Val acc: 83.59%
#
# New best model: 83.59%
# Epoch 21/30
# Epoch 21/30 | Step 1/390 | LR: 0.000257 | Batch loss: 0.4275 | Batch acc: 85.94%
# Epoch 21/30 | Step 101/390 | LR: 0.000246 | Batch loss: 0.3200 | Batch acc: 86.72%
# Epoch 21/30 | Step 201/390 | LR: 0.000235 | Batch loss: 0.4272 | Batch acc: 82.03%
# Epoch 21/30 | Step 301/390 | LR: 0.000224 | Batch loss: 0.3550 | Batch acc: 86.72%
# End of epoch 21 | Val loss: 0.4958 | Val acc: 83.65%
#
# New best model: 83.65%
# Epoch 22/30
# Epoch 22/30 | Step 1/390 | LR: 0.000214 | Batch loss: 0.3010 | Batch acc: 86.72%
# Epoch 22/30 | Step 101/390 | LR: 0.000203 | Batch loss: 0.3249 | Batch acc: 91.41%
# Epoch 22/30 | Step 201/390 | LR: 0.000193 | Batch loss: 0.2709 | Batch acc: 91.41%
# Epoch 22/30 | Step 301/390 | LR: 0.000183 | Batch loss: 0.4657 | Batch acc: 83.59%
# End of epoch 22 | Val loss: 0.5017 | Val acc: 83.66%
#
# New best model: 83.66%
# Epoch 23/30
# Epoch 23/30 | Step 1/390 | LR: 0.000174 | Batch loss: 0.1639 | Batch acc: 93.75%
# Epoch 23/30 | Step 101/390 | LR: 0.000164 | Batch loss: 0.2726 | Batch acc: 89.84%
# Epoch 23/30 | Step 201/390 | LR: 0.000155 | Batch loss: 0.2547 | Batch acc: 90.62%
# Epoch 23/30 | Step 301/390 | LR: 0.000145 | Batch loss: 0.3682 | Batch acc: 85.94%
# End of epoch 23 | Val loss: 0.5199 | Val acc: 83.54%
#
# No improvement for 1 epoch(s)
# Epoch 24/30
# Epoch 24/30 | Step 1/390 | LR: 0.000137 | Batch loss: 0.3311 | Batch acc: 85.16%
# Epoch 24/30 | Step 101/390 | LR: 0.000128 | Batch loss: 0.2321 | Batch acc: 92.19%
# Epoch 24/30 | Step 201/390 | LR: 0.000120 | Batch loss: 0.2289 | Batch acc: 92.97%
# Epoch 24/30 | Step 301/390 | LR: 0.000112 | Batch loss: 0.2645 | Batch acc: 90.62%
# End of epoch 24 | Val loss: 0.4756 | Val acc: 84.90%
#
# New best model: 84.90%
# Epoch 25/30
# Epoch 25/30 | Step 1/390 | LR: 0.000105 | Batch loss: 0.3700 | Batch acc: 85.16%
# Epoch 25/30 | Step 101/390 | LR: 0.000097 | Batch loss: 0.1474 | Batch acc: 96.09%
# Epoch 25/30 | Step 201/390 | LR: 0.000089 | Batch loss: 0.2547 | Batch acc: 94.53%
# Epoch 25/30 | Step 301/390 | LR: 0.000082 | Batch loss: 0.2130 | Batch acc: 94.53%
# End of epoch 25 | Val loss: 0.5011 | Val acc: 84.44%
#
# No improvement for 1 epoch(s)
# Epoch 26/30
# Epoch 26/30 | Step 1/390 | LR: 0.000076 | Batch loss: 0.2143 | Batch acc: 90.62%
# Epoch 26/30 | Step 101/390 | LR: 0.000070 | Batch loss: 0.2955 | Batch acc: 89.06%
# Epoch 26/30 | Step 201/390 | LR: 0.000064 | Batch loss: 0.2672 | Batch acc: 93.75%
# Epoch 26/30 | Step 301/390 | LR: 0.000058 | Batch loss: 0.2714 | Batch acc: 90.62%
# End of epoch 26 | Val loss: 0.4665 | Val acc: 85.24%
#
# New best model: 85.24%
# Epoch 27/30
# Epoch 27/30 | Step 1/390 | LR: 0.000053 | Batch loss: 0.2712 | Batch acc: 89.84%
# Epoch 27/30 | Step 101/390 | LR: 0.000048 | Batch loss: 0.2942 | Batch acc: 91.41%
# Epoch 27/30 | Step 201/390 | LR: 0.000043 | Batch loss: 0.2151 | Batch acc: 93.75%
# Epoch 27/30 | Step 301/390 | LR: 0.000038 | Batch loss: 0.2911 | Batch acc: 90.62%
# End of epoch 27 | Val loss: 0.4589 | Val acc: 85.23%
#
# No improvement for 1 epoch(s)
# Epoch 28/30
# Epoch 28/30 | Step 1/390 | LR: 0.000034 | Batch loss: 0.2965 | Batch acc: 90.62%
# Epoch 28/30 | Step 101/390 | LR: 0.000030 | Batch loss: 0.2327 | Batch acc: 92.19%
# Epoch 28/30 | Step 201/390 | LR: 0.000027 | Batch loss: 0.2323 | Batch acc: 92.97%
# Epoch 28/30 | Step 301/390 | LR: 0.000023 | Batch loss: 0.2711 | Batch acc: 90.62%
# End of epoch 28 | Val loss: 0.4630 | Val acc: 85.23%
#
# No improvement for 2 epoch(s)
# Epoch 29/30
# Epoch 29/30 | Step 1/390 | LR: 0.000021 | Batch loss: 0.2855 | Batch acc: 90.62%
# Epoch 29/30 | Step 101/390 | LR: 0.000018 | Batch loss: 0.2262 | Batch acc: 89.84%
# Epoch 29/30 | Step 201/390 | LR: 0.000016 | Batch loss: 0.2586 | Batch acc: 92.19%
# Epoch 29/30 | Step 301/390 | LR: 0.000014 | Batch loss: 0.3443 | Batch acc: 92.19%
# End of epoch 29 | Val loss: 0.4593 | Val acc: 85.29%
#
# New best model: 85.29%
# Epoch 30/30
# Epoch 30/30 | Step 1/390 | LR: 0.000013 | Batch loss: 0.3032 | Batch acc: 89.06%
# Epoch 30/30 | Step 101/390 | LR: 0.000011 | Batch loss: 0.3523 | Batch acc: 88.28%
# Epoch 30/30 | Step 201/390 | LR: 0.000011 | Batch loss: 0.2659 | Batch acc: 89.06%
# Epoch 30/30 | Step 301/390 | LR: 0.000010 | Batch loss: 0.1733 | Batch acc: 92.97%
# End of epoch 30 | Val loss: 0.4612 | Val acc: 85.20%
#
# No improvement for 1 epoch(s)
# Restored best model with accuracy: 85.29%

# %%
test_loss, test_acc = teacher_model.evaluate(test_images, test_labels, verbose=1)
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8529 - loss: 0.4593
# Test accuracy: 85.29%

# %% [markdown]
# ## Section 4: Save the Trained Model

# %%
teacher_model.save('teacher_model.keras')
print("Teacher Model Trained and Saved.")
# Out:
# Teacher Model Trained and Saved.

# %% [markdown]
# # **Student Model Implementation**

# %% [markdown]
# ## Section 1: Load the Teacher Model
#
# Make sure the `teacher_model.keras` trained from the previous part is saved. In this section, we load the teacher model and freeze its weights because we won't train it further.

# %%
# Make sure you have "teacher_model.keras" in your working directory.
teacher_model = tf.keras.models.load_model("teacher_model.keras")
teacher_model.trainable = False  # Freeze the teacher model

# %% [markdown]
# ## Section 2. Create the Student Model
#
# Here, we define a lightweight student model using MobileNetV2. The student model will be trained using knowledge distillation.

# %%
from tensorflow.keras.applications import MobileNetV2
def create_student_model():
    """
    Create a lightweight student model based on MobileNetV2.
    You can modify or extend this architecture as needed.
    """
    # Use MobileNetV2 as the base model without pre-trained weights.
    base_model = MobileNetV2(weights=None, include_top=False, input_shape=(32, 32, 3))
    x = layers.GlobalAveragePooling2D()(base_model.output)
    # modify or add extra layers.
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(10, activation='softmax')(x)
    model = models.Model(inputs=base_model.input, outputs=outputs)
    return model

student_model = create_student_model()

# %% [markdown]
# ## Section 3: Define the Distiller
#
# The distiller class handles the custom training loop for knowledge distillation. It calculates a combined loss from:
# - **Hard Loss:** The standard cross entropy loss between the student's predictions and the true labels.
# - **Soft Loss:** The distillation loss between the teacher’s and student's predictions (using KL divergence).

# %%
class Distiller(tf.keras.Model):
    """
    Handles the custom training loop for knowledge distillation:
    - Uses teacher predictions (soft targets).
    - Uses student predictions.
    - Calculates a combined loss (hard + soft).
    """
    def __init__(self, student, teacher):
        super(Distiller, self).__init__()
        self.student = student
        self.teacher = teacher

    def compile(self, optimizer, metrics, student_loss_fn, distillation_loss_fn, alpha=0.1, temperature=3):
        super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        x, y = data

        # Obtain teacher predictions (teacher is frozen)
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Compute student predictions for x.
            student_predictions = self.student(x, training=True)

            # Compute the cross entropy loss (hard loss)
            student_loss = self.student_loss_fn(y, student_predictions)

            # Compute the distillation loss (soft loss)
            distillation_loss = self.distillation_loss_fn(teacher_predictions, student_predictions, self.temperature)

            # Combine the two losses (hard and soft)
            loss = (self.alpha * student_loss) + ((1 - self.alpha) * distillation_loss)

        # Compute gradients and update the student model's trainable variables.
        gradients = tape.gradient(loss, self.student.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.student.trainable_variables))

        # Update metrics
        self.compiled_metrics.update_state(y, student_predictions)
        results = {m.name: m.result() for m in self.metrics}
        results["loss"] = loss
        return results

    def test_step(self, data):
        x, y = data

        # Compute student predictions in inference mode.
        y_pred = self.student(x, training=False)

        # Compute the student loss comparing y_pred to y.
        student_loss = self.student_loss_fn(y, y_pred)

        # Update metrics
        self.compiled_metrics.update_state(y, y_pred)
        results = {m.name: m.result() for m in self.metrics}
        results["loss"] = student_loss
        return results

# %% [markdown]
# ## Section 4: Define Loss Functions
#
# Define the loss functions used in the distillation process:
# - **Cross Entropy Loss:** Standard loss between student predictions and true labels.
# - **Distillation Loss:** Uses KL divergence to measure the difference between the softened predictions of the teacher and student.

# %%
# Hard label loss (student vs. ground truth)
student_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

# Distillation loss function (KL divergence)
def distillation_loss_fn(teacher_logits, student_logits, temperature):
    """
    Compute the distillation loss using KL divergence.
    """
    epsilon = 1e-7

    teacher_log_probs = tf.math.log(tf.clip_by_value(teacher_logits, epsilon, 1.0))
    student_log_probs_raw = tf.math.log(tf.clip_by_value(student_logits, epsilon, 1.0))

    # Compute teacher probabilities using softmax with temperature scaling.
    teacher_probs = tf.nn.softmax(teacher_log_probs / temperature, axis=1)
    teacher_probs = tf.stop_gradient(teacher_probs)

    # Compute student log-probabilities using log-softmax with temperature scaling.
    student_log_probs = tf.nn.log_softmax(student_log_probs_raw / temperature, axis=1)

    # Compute the KL divergence loss and return it.
    KL_per_sample = teacher_probs * (tf.math.log(teacher_probs + epsilon) - student_log_probs)
    KL_per_sample = tf.reduce_sum(KL_per_sample, axis=1)

    k = tf.reduce_mean(KL_per_sample) * (temperature ** 2)

    return k

# %% [markdown]
# ## Section 5. Compile & Train the Distiller
#
# In this final section, we create an instance of the Distiller, compile it, and train it using the CIFAR-10 dataset. Optionally, data augmentation is applied.

# %%
# Create the Distiller instance.
distiller = Distiller(student=student_model, teacher=teacher_model)

# Compile the distiller.
distiller.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=student_loss_fn,
    distillation_loss_fn=distillation_loss_fn,
    alpha=0.3,       # Weight for the hard loss
    temperature=3    # Temperature for softening teacher predictions
)

# Load and normalize CIFAR-10 dataset.
from tensorflow.keras.preprocessing.image import ImageDataGenerator
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Optional: Data augmentation.
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(train_images)

# Train the distiller using the data generator.
distiller.fit(
    datagen.flow(train_images, train_labels, batch_size=128),
    epochs=15,
    validation_data=(test_images, test_labels)
)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py:670: UserWarning: `model.compiled_metrics()` is deprecated. Instead, use e.g.:
# ```
# for metric in self.metrics:
#     metric.update_state(y, y_pred)
# ```
#
#   return self._compiled_metrics_update_state(
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 91s 130ms/step - sparse_categorical_accuracy: 0.6365 - loss: 1.5532 - val_loss: 0.8622
# Epoch 2/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - sparse_categorical_accuracy: 0.6074 - loss: 1.5084 - val_loss: 1.9309
# Epoch 3/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - sparse_categorical_accuracy: 0.5811 - loss: 1.3517 - val_loss: 3.9845
# Epoch 4/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - sparse_categorical_accuracy: 0.5745 - loss: 1.2562 - val_loss: 2.8921
# Epoch 5/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - sparse_categorical_accuracy: 0.6753 - loss: 1.2259 - val_loss: 1.4357
# Epoch 6/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - sparse_categorical_accuracy: 0.6935 - loss: 1.0906 - val_loss: 1.7807
# Epoch 7/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 69ms/step - sparse_categorical_accuracy: 0.5749 - loss: 1.1741 - val_loss: 3.9391
# Epoch 8/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - sparse_categorical_accuracy: 0.5890 - loss: 1.0083 - val_loss: 2.3435
# Epoch 9/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - sparse_categorical_accuracy: 0.6817 - loss: 1.1023 - val_loss: 0.5516
# Epoch 10/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - sparse_categorical_accuracy: 0.7161 - loss: 1.1885 - val_loss: 0.2495
# Epoch 11/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - sparse_categorical_accuracy: 0.7423 - loss: 1.0241 - val_loss: 1.1431
# Epoch 12/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - sparse_categorical_accuracy: 0.7417 - loss: 0.8940 - val_loss: 1.6536
# Epoch 13/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - sparse_categorical_accuracy: 0.7456 - loss: 1.0325 - val_loss: 0.7528
# Epoch 14/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - sparse_categorical_accuracy: 0.7403 - loss: 0.9231 - val_loss: 0.6522
# Epoch 15/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - sparse_categorical_accuracy: 0.7513 - loss: 0.9554 - val_loss: 0.8212

# %%
results = distiller.evaluate(test_images, test_labels, verbose=1, return_dict=True)
print(f"Student test accuracy: {results['compile_metrics']['sparse_categorical_accuracy'].numpy() * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - sparse_categorical_accuracy: 0.7513 - loss: 0.8212
# Student test accuracy: 75.13%

# %% [markdown]
# ## Section 6: Save distilled student model

# %%
# Save the distilled student model
student_model.save("student_model.h5")
print("Student model saved.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Student model saved.

# %% [markdown]
# # **TensorFlow Lite Quantization**
#
# In this section, we convert the saved student model to TensorFlow Lite format using two different quantization methods:
# - **Float16 Weight-Only Quantization:** Converts model weights from float32 to float16.
# - **INT8 Weight-Only Quantization:** Converts model weights to int8 using a representative dataset for calibration while keeping activations in float32.

# %% [markdown]
# ## Section 1: FP16 Quantization

# %%
# Load the student model from a saved Keras model file.
student_model = tf.keras.models.load_model('student_model.h5')

# Create a TFLite converter from the student model.
converter = tf.lite.TFLiteConverter.from_keras_model(student_model)

# Set the converter optimizations to enable model compression.
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Define the target data type for quantization
# PS: float16 for weight-only quantization.
converter.target_spec.supported_types = [tf.float16]

# Convert the model to TFLite format.
tflite_model = converter.convert()

# Save the converted TFLite model to a file.
with open('student_model_float16_weights_only.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Saved artifact at '/tmp/tmpcozhs0iq'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   136222413796560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223256911440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223256907600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136222413836880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223256912976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769008016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769010704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769008592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769013200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769013008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769012432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769018000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769011280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769014352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769015696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769015888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990190672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990188368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769015312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136223769009360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990187984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990187792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990188176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990188752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990190288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990180304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990190096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990189712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990179920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990189520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990189328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990190480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990188944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990188560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990192016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990191440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990191632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990191824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990180112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990192976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990192400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990192592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990192784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990190864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990193936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990193360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990193552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990193744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990191056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990194896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990194320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990194512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990194704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990192208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990195856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990195280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990194128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990195664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990195472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990195088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990193168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001780176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001781328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219990196048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001780752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001781136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001779792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001779984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001780368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001782288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136222413841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001782864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001782096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001780560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001783248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001782672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001783056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001780944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001782480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001784208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001783632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001783824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001784016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001781520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001785168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001784592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001784784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001784976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001781712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001786128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001785552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001785744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001785936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001783440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001787088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001786512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001786704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001786896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001784400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001788048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001787472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001787664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001787856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001785360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001789008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001788432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001788624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001788816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001786320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001789968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001789392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001789584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001789776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001787280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001790928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001790352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001790544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001790736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001788240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001791888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001791312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001791504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001791696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001789200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001792848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001792272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001792464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001792656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001790160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001793808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001793232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001793424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001793616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001791120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001794768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001794192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001794384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001794576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001792080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001795728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001795152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001794000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001795536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001795344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001794960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001793040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002141584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002141776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220001795920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002140624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002140240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002141392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002141200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002141008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002142736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002142160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002142352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002142544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002140432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002143696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002143120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002143312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002143504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002140816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002144656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002144080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002144272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002144464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002141968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002145616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002145040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002145232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002145424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002142928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002146576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002146000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002146192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002146384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002143888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002147536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002146960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002147152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002147344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002144848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002148496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002147920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002148112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002148304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002145808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002149456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002148880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002149072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002149264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002146768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002150416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002149840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002150032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002150224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002147728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002151376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002150800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002150992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002151184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002148688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002152336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002151760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002151952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002152144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002149648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002153296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002152720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002152912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002153104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002150608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002154256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002153680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002153872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002154064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002151568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002155216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002154640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002154832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002155024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002152528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002156176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002155600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002154448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002155984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002155792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002155408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002153488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002485648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002485840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002156368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002484688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002484304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002485456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002485264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002485072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002486800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002486224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002486416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002486608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002484496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002487760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002487184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002487376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002487568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002484880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002488720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002488144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002488336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002488528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002486032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002489680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002489104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002489296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002489488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002486992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002490640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002490064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002487952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002491408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136220002490832: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# ## Section 2: INT8 Quantization
#
# Key Differences from FP16 Quantization
# - **Calibration**: Since the range of INT8 is too small, we need a calibration dataset to measure the min/max activation ranges, ensuring accurate FP-to-INT8 mapping.
# - **FP32 input/output**: Unlike FP16, full INT8 conversion might have default integer input/output tensors. We explicitly force them back to FP32 so the model remains compatible with our existing float image preprocessing.

# %%
# Load the CIFAR-10 test dataset for calibration.
(_, _), (test_images, _) = tf.keras.datasets.cifar10.load_data()
test_images = test_images.astype(np.float32) / 255.0

# A representative dataset generator for calibration.
def representative_data_gen():
    # Verify if 100 images are sufficient for calibration or adjust the count.
    for i in range(100):
        yield [test_images[i:i+1]]

# Load the student model from a saved Keras model file.
student_model = tf.keras.models.load_model('student_model.h5')

# Create a TFLite converter from the student model.
converter = tf.lite.TFLiteConverter.from_keras_model(student_model)

# Set the converter optimizations for weight quantization.
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Assign the representative dataset generator for calibration.
converter.representative_dataset = representative_data_gen

# Set the target operations to use only INT8 built-in ops.
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

# Keep activations as float32 for compatibility.
converter.inference_input_type = tf.float32
converter.inference_output_type = tf.float32

# Convert the model to TFLite format.
tflite_model = converter.convert()

# Save the converted TFLite model to a file.
with open('student_model_int8_weights_only_cifar.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Saved artifact at '/tmp/tmppk4q70_u'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   136219775430160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775434576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775427472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775429776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775434192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775429968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775429200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775434384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775430352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775433232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775433808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775433616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775433424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775429584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775432272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775432848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775432656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775432464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775429392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775431312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775431888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775431696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775431504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775434000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775427856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775430928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775430736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775431120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775428432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775428048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775432080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775427664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775428624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775428240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219775433040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782218768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782217808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782218000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782218384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782219728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782219152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782219344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782219536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782218960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782220688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782220112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782220304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782220496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782218576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782221648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782221072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782221264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782221456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782218192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782222608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782222032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782222224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782222416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782219920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782223568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782222992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782223184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782223376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782220880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782224528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782223952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782224144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782224336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782221840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782225488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782224912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782225104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782225296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782222800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782225872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782226064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782223760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782227408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782227024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782224720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782228368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782228176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782225680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782229328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782228944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782230096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782231248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782230672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782232208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782231632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782232016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782233168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782232592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782232784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782232400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782233936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782233360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782231440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782233744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219782230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781873744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781874320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781874512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781874128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781875664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781875088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781875280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781875472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781874704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781876624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781876048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781876240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781876432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781873936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781877584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781877008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781877200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781877392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781874896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781878544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781877968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781878160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781878352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781875856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781879504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781878928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781879120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781879312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781876816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781880464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781879888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781880080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781880272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781877776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781881424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781880848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781881040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781881232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781878736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781882384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781881808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781882000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781879696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781883344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781882768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781882960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781883152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781880656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781883728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781883920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781884112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781881616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781885264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781884688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781884880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781885072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781882576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781886224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781885648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781885840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781886032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781883536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781887184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781886608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781886800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781886992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781884496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781888144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781887568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781887760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781887952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781885456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781889104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781888528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781888720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781888336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781889872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781889296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781887376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781889488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781889680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781888912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219781886416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765833808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765834384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765834576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765834192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765835728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765835152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765835344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765835536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765834768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765836688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765836112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765836304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765836496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765834000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765837648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765837072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765837264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765837456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765834960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765838608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765838032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765838224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765838416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765835920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765839568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765838992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765839184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765839376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765836880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765840528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765839952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765840144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765840336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765837840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765841488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765840912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765841104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765838800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765842448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765841872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765842064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765842256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765839760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765843408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765842832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765843024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765843216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765840720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765844368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765843792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765843984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765844176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765841680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765845328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765844752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765842640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136219765845520: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(

# %% [markdown]
# # **Raspberry Pi Setup**

# %% [markdown]
# In this section, we will set up a Raspberry Pi 4 server through [Mythic Beasts](https://www.mythic-beasts.com/order/rpi/). This server will be used to deploy and run our quantized TensorFlow Lite models. Follow the steps below to get started.
#
#
#
#
# ## Prepare and Connect to Server
# ### 1. Purchase a Raspberry Pi 4 Server (approx 7-10 pounds)
# - Go to [Mythic Beasts Raspberry Pi](https://www.mythic-beasts.com/order/rpi/).
# - Choose the **Raspberry Pi 4 with at least 4GB RAM** monthly plan.
# - Complete the checkout process to finalize your purchase.
#
#
#
#
# ### 2. Name Your Server
# - During setup, you will have the option to name your server.
#
#
#
#
# ### 3. Generate SSH Keys
# To securely connect to your Raspberry Pi server, you will need SSH keys:
#
#
#
#
# - Open a terminal (on macOS/Linux) or use Git Bash/PowerShell (on Windows).
# - Generate a new SSH key pair (if you don’t already have one) by running:
#
#
#
#
#   ```bash
#   ssh-keygen -t rsa -b 4096
#   ```
#
#
#
#
# ### 4. Add Your SSH Public Key to Mythic Beasts
# - Log in to **Mythic Beasts** and access `https://www.mythic-beasts.com/customer/servers/rpi/`+ Name of Your Machine
# - Click the **Configure Keys** following the blue arrow in the picture.
# - Paste the **public** portion of your SSH key (the content of `~/.ssh/id_rsa.pub` or equivalent) into the key field.
# - Save the changes.
#
#
#
#
# ### 5. Connect to Your Raspberry Pi
#
#
# Once your server is set up and your SSH key has been added, copy the SSH command shown in your Raspberry Pi hosting dashboard. The command usually includes the SSH username, host, and port number.
#
#
# Open a terminal and connect using:
#
#
# ```bash
# ssh -p <PORT> <USERNAME>@<HOST>
# ```
#
#
# For example, if your dashboard lists port `5244`, username `root`, and host `ssh.examplepi.com`, the command would look like:
#
#
# ```bash
# ssh -p 5244 root@ssh.examplepi.com
# ```
#
#
# When connecting for the first time, SSH may ask whether you trust the host fingerprint. Type `yes` to continue. After that, you should be logged into the Raspberry Pi terminal.

# %% [markdown]
# ## Setup Server Environment
# 1. **Set the Time:**
# If the initial device time is incorrect, you will be unable to use network-based tools like wget and apt. Therefore, you may need to manually set it to the correct time.
#     ```bash
#     date -s "$(wget -qSO- --max-redirect=0 google.com 2>&1 | grep Date: | cut -d' ' -f5-8)Z"
#     ```
# 2. **Install Packages:**
# Install the required python modules. Due to the PEP668 restriction on the device, tflite-runtime must be installed in the user directory using the parameters below. Alternatively, you can use venv, which is a more elegant method.
#     ```
#     apt install python3-pip python3-pil python3-numpy python3-psutil libopenjp2-7 libopenblas0
#     pip install tflite-runtime --break-system-packages
#     ```
# 3. **Miscellaneous:**
# Different devices may encounter different minor issues during configuration. Please read the error messages carefully, follow the system's prompts to install supplemental dependencies.

# %% [markdown]
# ## **Transferring Files to Server**
#
# To transfer files from your local machine to a Raspberry Pi hosted by Mythic Beasts, use the `scp` command and the port of your own configuration.
#
# ### Command Format
#
# ```sh
# scp -P 5244 "/path/to/local/file" root@ssh.your-hostedpi.com:/path/to/destination/
# ```
# ### Example Command
# ``` sh
# scp -P 5244 "~/Documents/my_script.py" root@ssh.examplepi.com:/home/pi/
# ```
# ### Important Instructions:
# - Check the **port** of the configuration of your own server.
# - Ensure that the file transfer completes **100%** before proceeding.
# - If the `scp` command is interrupted or incomplete, your files may be **corrupted**, leading to runtime errors.
# - Always **wait for the command to fully execute** before disconnecting.
#
# ## **NOTE** :
# For now transfer both the **"student_model_int8_weights_only_cifar.tflite"** and **"student_model_float16_weights_only.tflite"** to the raspberry pi using SCP command. The above setup was for macos it follows similarly for windows systems as well you can find it online i.e (how to setup scp,ssh etc ).

# %%
import os

print(os.getcwd())
print(os.listdir("/content"))
# Out:
# /content
# ['.config', 'teacher_model.keras', 'student_model_int8_weights_only_cifar.tflite', 'student_model.h5', 'student_model_float16_weights_only.tflite', 'sample_data']

# %%
from google.colab import files

files.download("/content/student_model_float16_weights_only.tflite")
files.download("/content/student_model_int8_weights_only_cifar.tflite")

# %% [markdown]
# # Experiments on Raspberry Pi

# %% [markdown]
# ## Downloading Images on Server
# Run the following code on raspberry pi

# %%
# NOTE: Do not run this on Colab
mkdir -p images
wget -O images/image1_frog.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/frog1.png
wget -O images/image2_automobile.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/automobile1.png
wget -O images/image3_truck.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/truck1.png
wget -O images/image4_airplane.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/airplane1.png
wget -O images/image5_ship.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/ship1.png
wget -O images/image6_deer.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/deer1.png
wget -O images/image7_dog.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/dog1.png
wget -O images/image8_horse.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/horse1.png
wget -O images/image9_bird.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/bird1.png
wget -O images/image10_cat.jpg https://www.cs.toronto.edu/~kriz/cifar-10-sample/cat1.png

# %% [markdown]
# ## **Running Inference on Server**
# After transferring the **TFLite models** and downloading the **images**, the next step is to **run inference** using the `Inference.py` script.
#
# ---
#
# ### **Setup Requirements**
# Ensure that:
# - The **quantized models** (`student_model_float16_weights_only.tflite`, `student_model_int8_weights_only_cifar.tflite`) are in the working directory.
# - The **test images** are inside the `images/` folder.
# - The required **libraries** (`tflite_runtime`, `PIL`, `numpy`, `psutil`, `shutil`) are installed.
#
# ---
#
# ### **Inference Script**
#
# This section prepares a standalone inference script for running the quantized models on an edge device.
#
# The script will:
# - Load the **TFLite models**.
# - Preprocess images and run inference.
# - Measure CPU, memory, and temperature usage.
#
# Once completed, **transfer `Inference.py` to the Raspberry Pi using SCP** and run inference to analyze performance.
#
#  **Complete the script, transfer it, and start running inference!**
#
# ---

# %%
from tflite_runtime.interpreter import Interpreter
from PIL import Image
import numpy as np
import time
import os
import psutil
import shutil

# List of models to test
models = [
    "student_model_float16_weights_only.tflite",
    "student_model_int8_weights_only_cifar.tflite"
]

# Path to images folder
image_folder = "images/"
image_files = sorted([f for f in os.listdir(image_folder) if f.endswith(('.jpg', '.png'))])

# Ensure images exist
if not image_files:
    print("No images found in the 'images/' folder. Please add images before running inference.")
    exit()

# Function to get CPU temperature
def get_cpu_temp():
    try:
        with open("/sys/class/thermal/thermal_zone0/temp", "r") as f:
            return int(f.read().strip()) / 1000.0  # Convert from millidegrees to Celsius
    except Exception:
        return None

# Function to preprocess images
def preprocess_image(image_path, input_shape, dtype=np.float32):
    """Load and preprocess an image to match the model's expected input shape."""
    img = Image.open(image_path).resize((input_shape[1], input_shape[2]))
    img_array = np.array(img).astype(dtype) / 255.0  # Normalize

    # INT8 models require int8 inputs, so scale correctly
    if dtype == np.int8:
        img_array = (img_array * 255 - 128).astype(np.int8)

    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# -------------------------------
# Function to run inference
# -------------------------------

def run_inference(model_path, image_path):
    """Run inference on a quantized TFLite model and collect performance data."""
    try:
        # 1) Load the TFLite model using the Interpreter.
        interpreter = Interpreter(model_path=model_path)

        # 2) Allocate memory for model tensors.
        interpreter.allocate_tensors()

        # 3) Retrieve model input and output tensor details.
        input_details = interpreter.get_input_details()
        output_details = interpreter.get_output_details()

        # 4) Extract input shape and data type.
        input_shape = input_details[0]['shape']
        input_dtype = input_details[0]['dtype']

        # 5) Load and preprocess the image to match the model’s input format.
        sample_input = preprocess_image(image_path, input_shape, input_dtype)

        # 6) Measure CPU and memory usage before inference using psutil
        cpu_before = psutil.cpu_percent(interval=None)
        mem_before = psutil.virtual_memory().percent
        temp_before = get_cpu_temp()

        # 7) Perform inference
        start_time = time.time()
        interpreter.set_tensor(input_details[0]["index"], sample_input)
        interpreter.invoke()
        end_time = time.time()

        # 8) Retrieve the output tensor from the model.
        output_data = interpreter.get_tensor(output_details[0]['index'])

        # 9) Determine the predicted class from the output.
        predicted_class = int(np.argmax(output_data, axis=1)[0])

        # 10) Measure CPU and memory usage after inference.
        cpu_after = psutil.cpu_percent(interval=None)
        mem_after = psutil.virtual_memory().percent
        temp_after = get_cpu_temp()

        return {
            "model": model_path,
            "image": os.path.basename(image_path),
            "inference_time": round(end_time - start_time, 4),
            "predicted_class": predicted_class,
            "cpu_before": cpu_before,
            "cpu_after": cpu_after,
            "mem_before": mem_before,
            "mem_after": mem_after,
            "temp_before": temp_before,
            "temp_after": temp_after
        }

    except Exception as e:
        print(f"Inference failed for {model_path} on {image_path}: {e}")
        return None


# Store results for final summary
results = []

# Run inference on all images using both models
for model in models:
    print(f"\nRunning inference with model: {model}\n" + "="*60)
    for image_file in image_files:
        image_path = os.path.join(image_folder, image_file)
        result = run_inference(model, image_path)
        if result:
            results.append(result)

# Final Summary Table
shutil.get_terminal_size((80, 20))  # Ensure table formatting works well
print("\nFinal Inference Summary")
print("=" * 80)
print(f"{'Model':<40} {'Image':<20} {'Time (s)':<10} {'Pred Class':<12} {'CPU (%)':<12} {'Mem (%)':<10} {'Temp (°C)':<10}")
print("=" * 80)

for res in results:
    print(f"{res['model']:<40} {res['image']:<20} {res['inference_time']:<10} {res['predicted_class']:<12} {res['cpu_after']:<12} {res['mem_after']:<10} {res['temp_after']:<10}")

print("=" * 80)
print("Inference Completed.")

# %% [markdown]
# ## Inference Results and Discussion

# %% [markdown]
# Results:
#
# ![Inference.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Inference Time
#
# **Question:** Compare the execution times for different models. Which model runs faster? How does quantization affect speed?
#
# **Answer:**
# The INT8 quantized model ran much faster than the FP16 model. From the summary table, the FP16 model took about 0.074–0.077 s per image, while the INT8 model took about 0.0074–0.0079 s per image. This means the INT8 model was roughly 10× faster on the Raspberry Pi. This result makes sense because the INT8 model uses fewer bits, and integer computations are generally more efficient. In conclusion, quantization improved inference speed significantly because INT8 arithmetic requires less computation and memory bandwidth than FP16 on the Raspberry Pi.
#
# ---
#
# ## 2. CPU and Memory Usage
#
# **Question:** Observe CPU and memory utilization before and after inference. Do different models show significant differences in resource consumption?
#
#
# **Answer:**
# The two models showed only modest differences in CPU and memory usage. However, the quantized INT8 model had slightly lower memory usage overall, and lower CPU usage in most cases compared to the FP16 model. The FP16 model used around 4.7–4.8% memory, while the INT8 model used around 4.4% memory. CPU readings varied across runs, so there was not a perfectly consistent trend, but both models stayed within a similar low-to-moderate CPU range. In most cases, the FP16 model did show slightly higher CPU usage. Temperature also stayed very similar, around 41–43°C, and neither model caused a major increase in temperature during the inference runs.
#
# ---
#
# ## 3. Prediction Consistency
#
# **Question:** Look at the predicted classes. Are the models making consistent predictions across different images?
#
# **Answer:**
# The two models produced the same predicted class for all 10 images, so their predictions were fully consistent with each other. Most predictions matched the expected image categories, although a small number of images were misclassified. More specifically, both models got 8 out of 10 predictions correct. Both models predicted the cat image as dog and the frog image as cat. The rest of the predictions were accurate. Overall, quantization did not change the model’s prediction behavior on these sample images, which suggests that compression preserved the student model’s inference quality well.
